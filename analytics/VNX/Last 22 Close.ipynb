# %%
import warnings
warnings.filterwarnings('ignore')

import os
import sys
import numpy as np

BACKTESTING_MODULE_PATH = os.path.abspath('../backtest')
sys.path.insert(1, BACKTESTING_MODULE_PATH)
from backtesting.backtesting import Backtest, Strategy

METHOD_MODULE_PATH = os.path.abspath('../')
sys.path.insert(1, METHOD_MODULE_PATH)
import method.Ticker as Ticker
import method.SaleRules as _sr
import method.algofuncs as _af
path = os.getcwd()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>

# %%
DATA_PATH = os.path.abspath('../vn-stock-data/VNX/')
ticker_id = 'TCH'
ticker_data = _af.get_pricing_by_path(DATA_PATH + '/' + ticker_id+'.csv', '2018-01-01')
ticker_data.tail(22)
# Out:
#              Open   High    Low  Close    Volume       Date
# Date
# 2020-11-10  18.90  19.00  18.60  18.80   5280320 2020-11-10
# 2020-11-11  18.65  18.75  18.45  18.55   7274850 2020-11-11
# 2020-11-12  18.60  18.75  18.45  18.70   3366410 2020-11-12
# 2020-11-13  18.70  18.70  18.50  18.65   1714110 2020-11-13
# 2020-11-16  18.65  18.70  18.10  18.10   3215370 2020-11-16
# 2020-11-17  18.20  18.75  18.10  18.75   8399350 2020-11-17
# 2020-11-18  18.60  18.95  18.50  18.85   5918250 2020-11-18
# 2020-11-19  18.70  19.05  18.55  19.00   8325970 2020-11-19
# 2020-11-20  19.15  20.30  19.15  20.30  11655810 2020-11-20
# 2020-11-23  20.70  21.30  19.80  20.85  16584510 2020-11-23
# 2020-11-24  20.80  20.80  20.00  20.10   8262730 2020-11-24
# 2020-11-25  20.15  20.20  19.50  20.15   8672770 2020-11-25
# 2020-11-26  20.30  20.75  20.25  20.65  11578480 2020-11-26
# 2020-11-27  20.65  20.65  20.20  20.20   5437700 2020-11-27
# 2020-11-30  20.25  20.45  19.50  19.50   9693850 2020-11-30
# ...

# %%
last22 = ticker_data.tail(22)
last5 = ticker_data.tail(5)

# %%
min22ByClose = last22[last22.Close == last22.Close.min()]
min22ByClose
# Out:
#              Open  High   Low  Close   Volume       Date
# Date
# 2020-11-16  18.65  18.7  18.1   18.1  3215370 2020-11-16

# %%
minClose22 = min22ByClose.Close.values[0]
minClose22
# Out:
# 18.1

# %%
max22ByClose = last22[last22.Close == last22.Close.max()]
max22ByClose
# Out:
#             Open  High   Low  Close    Volume       Date
# Date
# 2020-11-23  20.7  21.3  19.8  20.85  16584510 2020-11-23

# %%
maxClose22 = max22ByClose.Close.values[0]
maxClose22
# Out:
# 20.85

# %%
diffClose22 = (maxClose22 - minClose22)*100/maxClose22
diffClose22
# Out:
# 13.189448441247002

# %%
min5ByClose = last5[last5.Close == last5.Close.min()]
minClose5 = min5ByClose.Close.values[0]
max5ByClose = last5[last5.Close == last5.Close.max()]
maxClose5 = max5ByClose.Close.values[0]
diffClose5 = (maxClose5 - minClose5)*100/maxClose5
diffClose5
# Out:
# 4.987531172069826

# %%
last22.Close.values[-1] < last22.Close.values[-2] and last22.Close.values[-2] < last22.Close.values[-3]
# Out:
# True
