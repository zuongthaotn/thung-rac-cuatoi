# %% [markdown]
# # OHCL - Analytics

# %% [markdown]
# ### Import Library

# %%
import numpy as np
import pandas as pd
import numpy as np
import pandas_ta as ta
import seaborn as sns

import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [12, 6]
plt.rcParams['figure.dpi'] = 120
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Load Price Data

# %%
import os
from pathlib import Path
notebook_path = os.getcwd()
algo_dir = Path(notebook_path).parent.parent
csv_file = str(algo_dir) + '/VN30ps/neat/clusters/VN30F1M_5m_data_train.csv'
is_file = os.path.isfile(csv_file)
if is_file:
    dataset = pd.read_csv(csv_file, index_col='Date', parse_dates=True)
else:
    print('remote')
    dataset = pd.read_csv("https://raw.githubusercontent.com/zuongthaotn/vn-stock-data/main/VN30ps/VN30F1M_5minutes.csv", index_col='Date', parse_dates=True)

# %%
data = dataset.copy()

# %%
data
# Out:
#                        Open    High     Low   Close  Volume  \
# Date
# 2024-04-26 14:10:00  1226.4  1231.4  1226.1  1229.8    9819
# 2024-04-26 14:15:00  1229.9  1230.5  1227.3  1229.4    7567
# 2024-04-26 14:20:00  1229.8  1235.9  1229.4  1232.4   15934
# 2024-04-26 14:25:00  1232.5  1236.5  1232.1  1232.1   13075
# 2024-04-26 14:30:00  1232.3  1232.3  1232.3  1232.3     404
# ...                     ...     ...     ...     ...     ...
# 2024-10-17 14:15:00  1360.0  1361.5  1357.7  1358.1    7440
# 2024-10-17 14:20:00  1358.2  1359.5  1358.2  1358.4    3831
# 2024-10-17 14:25:00  1358.4  1358.6  1358.1  1358.5    6374
# 2024-10-17 14:30:00  1358.5  1358.5  1358.4  1358.4     128
# 2024-10-17 14:45:00  1358.3  1358.3  1358.3  1358.3    5680
#
#                                  current  min_OC  max_OC   max_3   min_3  ...  \
# Date                                                                      ...
# 2024-04-26 14:10:00  2024-04-26 14:15:00  1226.4  1229.8  1231.9  1226.1  ...
# ...

# %%
len(data.cluster1.unique())
# Out:
# 97

# %%
len(data.cluster2.unique())
# Out:
# 199

# %%
len(data.cluster3.unique())
# Out:
# 53

# %%
len(data.vol_rate.unique())
# Out:
# 362

# %%
data.vol_rate.describe()
# Out:
# count    6072.000000
# mean        1.033007
# std         0.677694
# min         0.000000
# 25%         0.560000
# 50%         0.870000
# 75%         1.360000
# max         7.960000
# Name: vol_rate, dtype: float64

# %%
len(data[data.in_position==1])
# Out:
# 5776

# %%
len(data[data.in_position!=1])
# Out:
# 296

# %%
data.tail(50)
# Out:
#                        Open    High     Low   Close  Volume  \
# Date
# 2024-10-17 09:05:00  1358.7  1358.9  1357.8  1358.3    2053
# 2024-10-17 09:10:00  1358.2  1358.5  1358.1  1358.5    1346
# 2024-10-17 09:15:00  1358.5  1359.2  1358.2  1358.2    2582
# 2024-10-17 09:20:00  1358.4  1358.4  1357.1  1357.8    2705
# 2024-10-17 09:25:00  1357.8  1358.3  1357.5  1357.6    1431
# 2024-10-17 09:30:00  1357.6  1357.9  1357.1  1357.1    1041
# 2024-10-17 09:35:00  1357.1  1357.4  1356.4  1357.4    2960
# 2024-10-17 09:40:00  1357.4  1357.4  1356.9  1356.9     889
# 2024-10-17 09:45:00  1357.0  1357.4  1356.1  1357.1    1865
# 2024-10-17 09:50:00  1357.1  1357.2  1356.1  1356.4    1677
# 2024-10-17 09:55:00  1356.4  1356.9  1356.2  1356.2     951
# 2024-10-17 10:00:00  1356.3  1356.4  1355.7  1355.9    1962
# 2024-10-17 10:05:00  1356.0  1356.0  1355.3  1355.4    1798
# 2024-10-17 10:10:00  1355.3  1355.5  1354.8  1355.0    3082
# ...
