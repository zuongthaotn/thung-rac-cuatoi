# %% [markdown]
# # OHCL - Analytics

# %% [markdown]
# ### Import Library

# %%
import numpy as np
import pandas as pd
import numpy as np
import pandas_ta as ta
import seaborn as sns

import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [12, 6]
plt.rcParams['figure.dpi'] = 120
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Load Price Data

# %%
import os
from pathlib import Path
notebook_path = os.getcwd()
algo_dir = Path(notebook_path).parent.parent
csv_file = str(algo_dir) + '/vn-stock-data/VN30ps/VN30F1M_5minutes.csv'
is_file = os.path.isfile(csv_file)
if is_file:
    dataset = pd.read_csv(csv_file, index_col='Date', parse_dates=True)
else:
    print('remote')
    dataset = pd.read_csv("https://raw.githubusercontent.com/zuongthaotn/vn-stock-data/main/VN30ps/VN30F1M_5minutes.csv", index_col='Date', parse_dates=True)

# %%
data = dataset.copy()

# %%
# data = data[(data.index > '2020-11-01 00:00:00') & (data.index < '2024-10-01 00:00:00')]
data = data[data.index > '2020-11-01 00:00:00']

# %%
data
# Out:
#                        Open    High     Low   Close  Volume
# Date
# 2020-11-02 09:00:00   900.1   900.2   899.3   900.1    1910
# 2020-11-02 09:05:00   900.2   900.2   898.7   899.4    1670
# 2020-11-02 09:10:00   899.5   900.0   899.0   899.5    1329
# 2020-11-02 09:15:00   899.4   899.5   898.2   898.6    1722
# 2020-11-02 09:20:00   898.5   898.6   896.5   898.2    2939
# ...                     ...     ...     ...     ...     ...
# 2025-02-14 14:15:00  1343.0  1343.0  1340.3  1341.3    7141
# 2025-02-14 14:20:00  1340.9  1341.9  1340.5  1341.4    4593
# 2025-02-14 14:25:00  1341.1  1342.5  1340.7  1342.5    4207
# 2025-02-14 14:30:00  1342.5  1342.5  1342.5  1342.5     150
# 2025-02-14 14:45:00  1341.8  1341.8  1341.8  1341.8    5684
#
# [54482 rows x 5 columns]

# %%
data["ema_fast"] = ta.ema(data["Close"], length=20)
data["ema_low"] = ta.ema(data["Close"], length=250)
data["ema_cross"] = ((data["ema_fast"] > data["ema_low"]) & (data["ema_fast"].shift(1) <= data["ema_low"].shift(1)) | (data["ema_fast"] < data["ema_low"]) & (data["ema_fast"].shift(1) >= data["ema_low"].shift(1)))

# %%
data[data.ema_cross == True]
# Out:
#                        Open    High     Low   Close  Volume     ema_fast  \
# Date
# 2020-11-09 09:00:00   914.2   915.2   913.8   914.6    2604   909.118854
# 2020-11-11 14:10:00   915.2   915.8   912.6   912.6    5683   918.032316
# 2020-11-11 14:45:00   921.4   921.4   921.4   921.4    5605   918.822408
# 2020-11-16 14:45:00   916.9   916.9   916.9   916.9    3978   926.606152
# 2020-11-17 14:15:00   931.2   932.5   930.8   932.2    6138   925.503509
# ...                     ...     ...     ...     ...     ...          ...
# 2025-02-04 13:40:00  1327.0  1328.6  1326.9  1327.9    2440  1326.119529
# 2025-02-10 09:50:00  1327.5  1328.0  1326.8  1327.9    2759  1334.554459
# 2025-02-12 09:10:00  1340.2  1341.2  1340.1  1340.8    3136  1333.899323
# 2025-02-13 09:10:00  1331.3  1331.7  1330.5  1330.8    2174  1334.956624
# 2025-02-13 13:45:00  1337.2  1338.5  1336.5  1336.9    4460  1334.380176
#
#                          ema_low  ema_cross
# Date
# 2020-11-09 09:00:00   908.879708       True
# 2020-11-11 14:10:00   918.540744       True
# 2020-11-11 14:45:00   918.586590       True
# 2020-11-16 14:45:00   926.709781       True
# 2020-11-17 14:15:00   925.322347       True
# ...                          ...        ...
# 2025-02-04 13:40:00  1326.024943       True
# 2025-02-10 09:50:00  1335.013120       True
# 2025-02-12 09:10:00  1333.480473       True
# 2025-02-13 09:10:00  1334.957820       True
# 2025-02-13 13:45:00  1334.148219       True
#
# [361 rows x 8 columns]

# %% [markdown]
# ### Preparing data for detecting TRAP

# %%
def cal_max_distance(r):
    if not r['ema_cross']:
        return 0
    if r['ema_fast'] > r['ema_low']:
        the_diff = round(r['ema_fast'] - r['min_emafast_25'])
    else:
        the_diff = round(r['max_emafast_25'] - r['ema_fast'])
    return the_diff
def cal_rsi_moving(r):
    if not r['ema_cross']:
        return 0
    if r['ema_fast'] > r['ema_low']:
        moving_len = r['RSI'] - r['min_5_rsi']
    else:
        moving_len = r['max_5_rsi'] - r['RSI']
    return moving_len

# %%
data['max_high_1dlater'] = data['High'].shift(-51).rolling(51).max()
data['min_low_1dlater'] = data['Low'].shift(-51).rolling(51).min()
data['RSI'] = ta.rsi(data["Close"], length=14)
data['RSI'] = round(data['RSI'])
data['min_5_rsi'] = data['RSI'].rolling(6).min()
data['max_5_rsi'] = data['RSI'].rolling(6).max()
data["body_size"] = abs(data["Close"] - data["Open"])
data["low_momentum"] = data["body_size"].rolling(5).mean() < data["body_size"].rolling(20).mean() * 0.5  # Small body filter
data['diff_cema'] = round(data['Close'] - data['ema_low'])
data["avg_volume"] = data["Volume"].rolling(25).mean()  # 1/2 day
data["diff_volume"] = round(data["Volume"] / data["avg_volume"], 1)
data['max_20'] = data['High'].rolling(25).max()
data['min_20'] = data['Low'].rolling(25).min()
data['diff_minmax_20'] = data['max_20'] - data['min_20']
data['diff_minmax_20'] = round(data['diff_minmax_20'])
data['avg_body_size'] = data["body_size"].rolling(5).mean()
data['body_size_on_avg'] = round(data['body_size'] / data['avg_body_size'], 1)
data['diff_ema'] = data['ema_fast'] - data['ema_low']
data["Cross_Speed"] = data["diff_ema"].diff(5) / 5
data["Cross_Speed"] = round(data["Cross_Speed"], 1)
data['max_diff_ema'] = data['diff_ema'].rolling(25).max()
data['max_diff_ema'] = round(data['max_diff_ema'])
data['min_diff_ema'] = data['diff_ema'].rolling(25).min()
data['min_diff_ema'] = round(data['min_diff_ema'])
data['avg_diff_ema'] = data['diff_ema'].rolling(6).mean()
data['avg_diff_ema'] = round(data['avg_diff_ema'], 1)
data['ibs'] = data.apply(lambda x: (0 if (x["High"] == x["Low"]) else round((x["Close"] - x["Low"]) / (x["High"] - x["Low"]), 1)), axis=1)
data['ibs'] = round(data['ibs'], 1)
data['avg_ibs'] = data['ibs'].rolling(5).mean()
data['avg_ibs'] = round(data['avg_ibs'], 1)
data['max_emafast_25'] = data['ema_fast'].rolling(25).max()
data['min_emafast_25'] = data['ema_fast'].rolling(25).min()

# %%
data.dropna(inplace=True)

# %%
data['max_emafast_distance'] = data.apply(lambda r: cal_max_distance(r), axis=1)
data['rsi_moving'] = data.apply(lambda r: cal_rsi_moving(r), axis=1)

# %%
def is_trap(r):
    trap = ''
    if r['ema_cross'] == True:
        if r['ema_fast'] > r['ema_low']:
            # Cross up
            if r['min_low_1dlater'] < r['Close'] - 3.5:
                trap = 'yes'
            else:
                trap = 'no'
        else:
            # Cross down
            if r['max_high_1dlater'] > r['Close'] + 3.5:
                trap = 'yes'
            else:
                trap = 'no'
    return trap

# %%
data['trap'] = data.apply(lambda r: is_trap(r), axis=1)

# %%
data[data.trap == 'yes'].tail(15)
# Out:
#                        Open    High     Low   Close  Volume     ema_fast  \
# Date
# 2024-07-29 09:20:00  1291.2  1291.5  1290.8  1291.4    2385  1285.078557
# 2024-07-30 10:05:00  1285.4  1285.8  1285.4  1285.8     411  1286.931226
# 2024-07-30 11:20:00  1287.2  1288.8  1287.2  1288.8    3974  1286.964432
# 2024-10-18 09:05:00  1376.5  1376.5  1374.5  1374.6    5041  1358.840761
# 2024-10-31 13:45:00  1342.5  1345.3  1342.2  1343.8   16422  1339.071768
# 2024-12-13 09:20:00  1332.5  1332.7  1331.8  1332.3    2805  1338.382557
# 2024-12-23 09:55:00  1329.2  1329.3  1329.0  1329.1     900  1325.399361
# 2024-12-24 09:55:00  1324.1  1324.2  1323.4  1323.6    1288  1325.814110
# 2025-01-02 10:40:00  1338.8  1339.4  1338.6  1339.2    4172  1344.951382
# 2025-01-16 09:35:00  1308.0  1308.5  1307.8  1308.0    2496  1302.315940
# 2025-01-16 13:10:00  1300.1  1301.0  1299.7  1300.5    1744  1302.196875
# 2025-02-03 09:55:00  1319.7  1319.8  1318.7  1319.0    2145  1328.814675
# 2025-02-10 09:50:00  1327.5  1328.0  1326.8  1327.9    2759  1334.554459
# 2025-02-12 09:10:00  1340.2  1341.2  1340.1  1340.8    3136  1333.899323
# 2025-02-13 09:10:00  1331.3  1331.7  1330.5  1330.8    2174  1334.956624
#
#                          ema_low  ema_cross  max_high_1dlater  \
# Date
# 2024-07-29 09:20:00  1284.990791       True            1294.7
# 2024-07-30 10:05:00  1286.954220       True            1298.3
# 2024-07-30 11:20:00  1286.932012       True            1300.9
# 2024-10-18 09:05:00  1357.982251       True            1376.8
# 2024-10-31 13:45:00  1338.968548       True            1347.8
# 2024-12-13 09:20:00  1338.728614       True            1339.1
# 2024-12-23 09:55:00  1325.168913       True            1330.5
# 2024-12-24 09:55:00  1325.955694       True            1337.7
# 2025-01-02 10:40:00  1345.369474       True            1346.9
# 2025-01-16 09:35:00  1301.973278       True            1312.7
# 2025-01-16 13:10:00  1302.289836       True            1312.7
# 2025-02-03 09:55:00  1329.317313       True            1327.7
# 2025-02-10 09:50:00  1335.013120       True            1337.6
# 2025-02-12 09:10:00  1333.480473       True            1342.0
# 2025-02-13 09:10:00  1334.957820       True            1348.9
#
#                      min_low_1dlater  ...  max_diff_ema  min_diff_ema  \
# Date                                  ...
# 2024-07-29 09:20:00           1284.2  ...           0.0          -7.0
# 2024-07-30 10:05:00           1284.6  ...           5.0          -0.0
# 2024-07-30 11:20:00           1284.6  ...           2.0          -0.0
# 2024-10-18 09:05:00           1363.0  ...           1.0          -7.0
# 2024-10-31 13:45:00           1333.6  ...           0.0          -3.0
# 2024-12-13 09:20:00           1331.7  ...           9.0          -0.0
# 2024-12-23 09:55:00           1322.5  ...           0.0          -8.0
# 2024-12-24 09:55:00           1321.7  ...           3.0          -0.0
# 2025-01-02 10:40:00           1337.1  ...           2.0          -0.0
# 2025-01-16 09:35:00           1295.1  ...           0.0          -5.0
# 2025-01-16 13:10:00           1295.1  ...           2.0          -0.0
# 2025-02-03 09:55:00           1313.5  ...          13.0          -1.0
# 2025-02-10 09:50:00           1326.8  ...           8.0          -0.0
# 2025-02-12 09:10:00           1329.5  ...           0.0          -3.0
# 2025-02-13 09:10:00           1326.2  ...           4.0          -0.0
#
#                      avg_diff_ema  ibs  avg_ibs  max_emafast_25  \
# Date
# 2024-07-29 09:20:00          -1.7  0.9      0.5     1285.078557
# 2024-07-30 10:05:00           0.3  1.0      0.5     1292.060111
# 2024-07-30 11:20:00          -0.2  1.0      0.7     1288.773221
# 2024-10-18 09:05:00          -2.0  0.0      0.3     1358.840761
# 2024-10-31 13:45:00          -0.7  0.5      0.7     1339.071768
# 2024-12-13 09:20:00           1.4  0.6      0.4     1347.718281
# 2024-12-23 09:55:00          -0.9  0.3      0.3     1325.399361
# 2024-12-24 09:55:00           0.5  0.2      0.5     1328.673232
# 2025-01-02 10:40:00           1.0  0.8      0.5     1347.836604
# 2025-01-16 09:35:00          -1.2  0.3      0.6     1302.315940
# 2025-01-16 13:10:00           0.5  0.6      0.6     1304.833319
# 2025-02-03 09:55:00           2.0  0.3      0.2     1343.013768
# 2025-02-10 09:50:00           1.3  0.9      0.4     1342.960288
# 2025-02-12 09:10:00          -1.1  0.6      0.4     1333.899323
# 2025-02-13 09:10:00           1.1  0.2      0.3     1339.232107
#
#                      min_emafast_25  max_emafast_distance  rsi_moving  trap
# Date
# 2024-07-29 09:20:00     1278.561549                     7         7.0   yes
# 2024-07-30 10:05:00     1286.931226                     5         0.0   yes
# 2024-07-30 11:20:00     1286.605073                     0        18.0   yes
# 2024-10-18 09:05:00     1351.157796                     8        16.0   yes
# 2024-10-31 13:45:00     1336.131371                     3        14.0   yes
# 2024-12-13 09:20:00     1338.382557                     9         7.0   yes
# 2024-12-23 09:55:00     1317.060948                     8         0.0   yes
# 2024-12-24 09:55:00     1325.814110                     3         1.0   yes
# 2025-01-02 10:40:00     1344.951382                     3        15.0   yes
# 2025-01-16 09:35:00     1296.901870                     5         3.0   yes
# 2025-01-16 13:10:00     1302.196875                     3         0.0   yes
# 2025-02-03 09:55:00     1328.814675                    14         5.0   yes
# 2025-02-10 09:50:00     1334.554459                     8         6.0   yes
# 2025-02-12 09:10:00     1330.470102                     3        24.0   yes
# 2025-02-13 09:10:00     1334.956624                     4         1.0   yes
#
# [15 rows x 35 columns]

# %%
len(data[data.trap == 'yes'])
# Out:
# 241

# %%
len(data[data.trap == 'no'])
# Out:
# 119

# %% [markdown]
# ## Analytics by EMA cross speed

# %%
group_by_ema_cross_speed = data[data.trap != ''].groupby(['Cross_Speed', 'trap'])['Cross_Speed'].count().rename({'Cross_Speed': 'count'})
group_by_ema_cross_speed.unstack().plot.bar()
# Out:
# <Axes: xlabel='Cross_Speed'>

# %% [markdown]
# ## Analytics by RSI moving

# %%
group_by_rsi_moving = data[data.trap != ''].groupby(['rsi_moving', 'trap'])['rsi_moving'].count().rename({'rsi_moving': 'count'})
group_by_rsi_moving.unstack().plot.bar()
# Out:
# <Axes: xlabel='rsi_moving'>

# %% [markdown]
# ## Analytics by min max diff_ema

# %% [markdown]
# ### Cross up

# %%
group_by_diff_ema_cross_up = data[(data.trap != '') & (data.ema_fast > data.ema_low)].groupby(['min_diff_ema', 'trap'])['min_diff_ema'].count().rename({'min_diff_ema': 'count'})
group_by_diff_ema_cross_up.unstack().plot.bar()
# Out:
# <Axes: xlabel='min_diff_ema'>

# %% [markdown]
# ## Analytics by EMA fast look back (max_emafast_distance)

# %%
group_by_max_distance= data[data.trap != ''].groupby(['max_emafast_distance', 'trap'])['max_emafast_distance'].count().rename({'max_emafast_distance': 'count'})
group_by_max_distance.unstack().plot.bar()
# Out:
# <Axes: xlabel='max_emafast_distance'>

# %% [markdown]
# ## Analytics by IBS

# %%
group_by_ibs= data[data.trap != ''].groupby(['ibs', 'trap'])['ibs'].count().rename({'ibs': 'count'})
group_by_ibs.unstack().plot.bar()
# Out:
# <Axes: xlabel='ibs'>

# %%
group_by_avg_ibs= data[data.trap != ''].groupby(['avg_ibs', 'trap'])['avg_ibs'].count().rename({'avg_ibs': 'count'})
group_by_avg_ibs.unstack().plot.bar()
# Out:
# <Axes: xlabel='avg_ibs'>

# %% [markdown]
# ## Analytics by avg_diff_ema

# %%
group_by_avg_diff_ema= data[data.trap != ''].groupby(['avg_diff_ema', 'trap'])['avg_diff_ema'].count().rename({'avg_diff_ema': 'count'})
group_by_avg_diff_ema.unstack().plot.bar()
# Out:
# <Axes: xlabel='avg_diff_ema'>

# %% [markdown]
# ## Analytics by Avg body size

# %%
group_by_body_size= data[data.trap != ''].groupby(['body_size_on_avg', 'trap'])['body_size_on_avg'].count().rename({'body_size_on_avg': 'count'})
group_by_body_size.unstack().plot.bar()
# Out:
# <Axes: xlabel='body_size_on_avg'>

# %% [markdown]
# ## Analytics by Min Max 20

# %%
group_by_diff_minmax = data[data.trap != ''].groupby(['diff_minmax_20', 'trap'])['diff_minmax_20'].count().rename({'diff_minmax_20': 'count'})
group_by_diff_minmax.unstack().plot.bar()
# Out:
# <Axes: xlabel='diff_minmax_20'>

# %% [markdown]
# ## low_momentum analytics

# %%
len(data[(data.trap == 'yes') & (data.low_momentum == True)])
# Out:
# 24

# %%
len(data[(data.trap == 'no') & (data.low_momentum == True)])
# Out:
# 19

# %% [markdown]
# ## Analytics by Volume

# %%
group_by_diff_volume = data[data.trap != ''].groupby(['diff_volume', 'trap'])['diff_volume'].count().rename({'diff_volume': 'count'})
group_by_diff_volume.unstack().plot.bar()
# Out:
# <Axes: xlabel='diff_volume'>

# %% [markdown]
# ## diff_cema analytics

# %%
trap_data = data[data.trap == 'yes']
notrap_data = data[data.trap == 'no']

# %%
y1 = np.full(len(trap_data['diff_cema']), 5)
y2 = np.full(len(notrap_data['diff_cema']), 4)
plt.scatter(trap_data['diff_cema'], y1, color='red')
plt.scatter(notrap_data['diff_cema'], y2, color='green')
plt.xlabel("Diff Close - lowEMA")
plt.ylabel("Nothing")
# Out:
# Text(0, 0.5, 'Nothing')

# %%
grdp = data[data.trap != ''].groupby(['diff_cema', 'trap'])['diff_cema'].count().rename({'diff_cema': 'count'})
grdp.unstack().plot.bar()
# Out:
# <Axes: xlabel='diff_cema'>

# %% [markdown]
# ## Analytics by RSI

# %%
group_by_rsi = data[data.trap != ''].groupby(['RSI', 'trap'])['RSI'].count().rename({'RSI': 'count'})
group_by_rsi.unstack().plot.bar()
# Out:
# <Axes: xlabel='RSI'>

# %% [markdown]
# ### Still RSI but just cross up

# %%
cross_up_group_by_rsi = data[(data.trap != '') & (data.ema_fast > data.ema_low)].groupby(['RSI', 'trap'])['RSI'].count().rename({'RSI': 'count'})
cross_up_group_by_rsi.unstack().plot.bar()
# Out:
# <Axes: xlabel='RSI'>
